# %%
import pickle
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import warnings
import optuna
from scipy.stats import spearmanr,pearsonr
from sklearn.model_selection import cross_val_score, StratifiedKFold, KFold, RandomizedSearchCV, cross_validate
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score,make_scorer
from tabpfn import TabPFNRegressor
from scipy.stats import spearmanr, uniform
import joblib
import os

# %%
warnings.filterwarnings('ignore')

def seed_everything(seed: int):
    import random, os
    import numpy as np
    import torch
    
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    
seed_everything(1234)

# %%
df_embeds = pd.read_csv('../../classical_ML/data/Orthrus_data/orthrus_features_clean.tsv.gz', sep='\t')
df_embeds.dropna(subset = ['embed0'], inplace=True)
embed_cols = [f'embed{i}' for i in range(512)]
df_embeds = df_embeds[['Transcript ID']+embed_cols]
df_embeds.rename(columns={"Transcript ID": "Transcript_ID"}, inplace=True)
df_embeds
# Out:
#          Transcript_ID    embed0    embed1    embed2    embed3    embed4  \
# 0      ENST00000263100  0.122282  0.177534 -0.048803 -0.165734 -0.034072
# 1      ENST00000373997  0.342975  0.134082  0.039255 -0.224912 -0.052249
# 2      ENST00000318602  0.331549  0.211808 -0.040499 -0.144805 -0.050687
# 3      ENST00000299698  0.337860  0.260349 -0.019156 -0.144985 -0.045211
# 4      ENST00000442999  0.120457  0.181139  0.107973 -0.104078 -0.039713
# ...                ...       ...       ...       ...       ...       ...
# 18479  ENST00000371528  0.189914  0.113874  0.061029 -0.105412 -0.031373
# 18480  ENST00000294353  0.223297  0.086196  0.052600 -0.128977 -0.027397
# 18481  ENST00000322764  0.254627  0.138448  0.156764 -0.182271  0.062424
# 18482  ENST00000381638  0.442461  0.263657 -0.102592 -0.080843  0.024760
# 18483  ENST00000370801  0.265919  0.088128  0.036297 -0.152144 -0.144289
#
#          embed5    embed6    embed7    embed8  ...  embed502  embed503  \
# ...

# %%
df_unq = pd.read_csv('../data/tcga_annotated_clean4ML.tsv.gz', sep='\t')
df_unq = df_unq.merge(df_embeds, how='left')
df_unq
# Out:
#      CHROM        POS REF ALT    Transcript_ID                      HGVSc  \
# 0        1     944753   C   T  ENST00000327044  ENST00000327044:c.2191C>T
# 1        1     952113   G   A  ENST00000327044  ENST00000327044:c.1218G>A
# 2        1    1255304   G   T  ENST00000349431   ENST00000349431:c.679G>T
# 3        1    1338573   G   T  ENST00000378888  ENST00000378888:c.1288G>T
# 4        1    1387314   C   T  ENST00000400809  ENST00000400809:c.1480C>T
# ...    ...        ...  ..  ..              ...                        ...
# 4013     X  152920717   C   T  ENST00000370268   ENST00000370268:c.622C>T
# 4014     X  153650171   G   T  ENST00000342782  ENST00000342782:c.1021G>T
# 4015     X  154030948   C   T  ENST00000303391   ENST00000303391:c.880C>T
# 4016     X  154354015   C   A  ENST00000369850  ENST00000369850:c.5586C>A
# 4017     X  154402790   C   T  ENST00000014935   ENST00000014935:c.826C>T
#
#       KIM_PTC_to_start_codon  KIM_upstream_exon_count  \
# ...

# %%
prot_feat_df = pd.read_csv('../data/protein_AA_features.tsv.gz', sep='\t')
prot_feat_df.rename(columns={'MANE-Select':'Transcript_ID'}, inplace=True)
prot_feat_df.drop(columns=['Unnamed: 0', 'Entry'], axis=1, inplace=True)
prot_feat_df
# Out:
#          Transcript_ID actual_or_pred_ACT_SITE  \
# 0      ENST00000436697                    pred
# 1      ENST00000709217                    pred
# 2      ENST00000374922                    pred
# 3      ENST00000637218                  actual
# 4      ENST00000469902                    pred
# ...                ...                     ...
# 18412  ENST00000295896                    pred
# 18413  ENST00000295898                    pred
# 18414  ENST00000306862                    pred
# 18415  ENST00000450660                    pred
# 18416  ENST00000420162                    pred
#
#                               annotation_actual_ACT_SITE  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      0000000000000000000000000000000000000000000000...
# 4                                                    NaN
# ...

# %%
# Calculate the proportion of lost features upon stop-gain
df_unq = df_unq.merge(prot_feat_df, how='left')

prot_feat_list = ['ACT_SITE', 'BINDING', 'COILED', 'COMPBIAS', 'DISULFID', 'BINDING', 'DOMAIN', 
                 'HELIX', 'MOD_RES', 'MOTIF', 'PROPEP', 'REGION', 'REPEAT', 'SIGNAL', 'STRAND',
                 'TOPO_DOM', 'TRANSIT', 'TRANSMEM', 'TURN', 'ZN_FING']

for prot_feat in prot_feat_list:
    df_unq[f'prop_lost_{prot_feat}'] = None

for idx, row in df_unq.iterrows():
    
    for prot_feat_name in prot_feat_list:
        temp_pred_or_actual = row[f'actual_or_pred_{prot_feat_name}']
        
        if not pd.isna(temp_pred_or_actual):
            
            prot_feat_binary = row[f'annotation_{temp_pred_or_actual}_{prot_feat_name}']
            
            if row['Protein_position'] <= len(prot_feat_binary):
                prot_feat_binary_lost = prot_feat_binary[row['Protein_position']:]
                df_unq.loc[idx, f'prop_lost_{prot_feat_name}'] = prot_feat_binary_lost.count('1') / len(prot_feat_binary)

prot_lost_feat_list = [f'prop_lost_{x}' for x in prot_feat_list]

# %%
def apply_baseline_rules(df, exon_len_threshold=407, penultimate_threshold=55, start_threshold=100):

    # long exon rule
    df['long_exon'] = 0
    df.loc[df['current_exon_len'] > exon_len_threshold, 'long_exon'] = 1

    # penultimate exon rule
    df['penultimate_flag'] = 0
    df.loc[
        (df['DIST_FROM_LAST_EXON'] < penultimate_threshold) &
        (df['DIST_FROM_LAST_EXON'] >= 0), 
        'penultimate_flag'
    ] = 1

    # close to start rule
    df['close_to_start'] = 0
    df.loc[df['CDS_position'] < start_threshold, 'close_to_start'] = 1

    return df

# %%
# last exon rule
df_unq['last_exon'] = 0
df_unq.loc[df_unq['current_exon_number']==df_unq['total_exon_numbers'], 'last_exon'] = 1

df_unq = apply_baseline_rules(df_unq, exon_len_threshold=355, penultimate_threshold=49, start_threshold=120)
df_unq
# Out:
#      CHROM        POS REF ALT    Transcript_ID                      HGVSc  \
# 0        1     944753   C   T  ENST00000327044  ENST00000327044:c.2191C>T
# 1        1     952113   G   A  ENST00000327044  ENST00000327044:c.1218G>A
# 2        1    1255304   G   T  ENST00000349431   ENST00000349431:c.679G>T
# 3        1    1338573   G   T  ENST00000378888  ENST00000378888:c.1288G>T
# 4        1    1387314   C   T  ENST00000400809  ENST00000400809:c.1480C>T
# ...    ...        ...  ..  ..              ...                        ...
# 4013     X  152920717   C   T  ENST00000370268   ENST00000370268:c.622C>T
# 4014     X  153650171   G   T  ENST00000342782  ENST00000342782:c.1021G>T
# 4015     X  154030948   C   T  ENST00000303391   ENST00000303391:c.880C>T
# 4016     X  154354015   C   A  ENST00000369850  ENST00000369850:c.5586C>A
# 4017     X  154402790   C   T  ENST00000014935   ENST00000014935:c.826C>T
#
#       KIM_PTC_to_start_codon  KIM_upstream_exon_count  \
# ...

# %%
my_features = ['last_exon', 'long_exon', 'penultimate_flag', 'close_to_start', 'hl',
       'mrl', 'cDNA_position', 'PERCENTILE', 'BP_DIST',
       'utr5_len', 'current_exon_len', 'VEST4_score', 'CADD_phred',
       'phyloP100way_vertebrate', 'dn_ds', 'abundance', 'shet',
       'lof.oe_ci.upper', 'lof.pRec', 'UTR5_GC',
       'prop_lost_DOMAIN',
       'TF', 'tau',
       'phastCons100way_vertebrate', 'phastCons17way_primate',
       'phastCons470way_mammalian', 'mis.z_score',
       'fathmm-XF_coding_score',
       'Cytoplasm', 'Ribosome', 'Membrane',
       'embed8', 'embed90', 'embed145',
       'embed205', 'embed219', 'embed230', 'embed240', 'embed254', 'embed309',
       'embed356', 'embed430']

# %% [markdown]
# ### Splits

# %%
test_var_ids = df_unq[df_unq['CHROM'].isin(['20', '21', '22'])]['HGVSc'].values.tolist()
test_var_ids = list(set(test_var_ids))
test_var_ids[0:5], len(test_var_ids)
# Out:
# (['ENST00000350028:c.1165G>T',
#   'ENST00000343380:c.565C>T',
#   'ENST00000377191:c.1258G>T',
#   'ENST00000349014:c.2359G>T',
#   'ENST00000377710:c.456G>A'],
#  224)

# %%
val_var_ids = df_unq[df_unq['CHROM']=='19']['HGVSc'].values.tolist()
val_var_ids = list(set(val_var_ids))
val_var_ids[0:5], len(val_var_ids)
# Out:
# (['ENST00000432763:c.1654C>T',
#   'ENST00000340790:c.1321G>T',
#   'ENST00000221480:c.190C>T',
#   'ENST00000254321:c.1654C>T',
#   'ENST00000253727:c.530C>A'],
#  204)

# %%
train_var_ids = list(set(df_unq.HGVSc.values.tolist()) - set(val_var_ids) - set(test_var_ids))
train_var_ids[0:5], len(train_var_ids)
# Out:
# (['ENST00000304043:c.283C>T',
#   'ENST00000491415:c.85G>T',
#   'ENST00000311806:c.1180C>T',
#   'ENST00000352689:c.1892T>G',
#   'ENST00000358173:c.2215C>T'],
#  3590)

# %% [markdown]
# ### splits

# %%
X_train_full = df_unq[df_unq['HGVSc'].isin(val_var_ids+train_var_ids)][my_features]
y_train_full = df_unq[df_unq['HGVSc'].isin(val_var_ids+train_var_ids)]['NMD_efficiency']

X_test = df_unq[df_unq['HGVSc'].isin(test_var_ids)][my_features]
y_test = df_unq[df_unq['HGVSc'].isin(test_var_ids)]['NMD_efficiency']

# %%
feature_means = X_train_full.mean()
feature_stds = X_train_full.std()

# %%
'''X_train_full = X_train_full.fillna(feature_means)
X_test = X_test.fillna(feature_means)

X_train_full = (X_train_full - feature_means) / (feature_stds + 1e-8)
X_test = (X_test - feature_means) / (feature_stds + 1e-8)'''
# Out:
# 'X_train_full = X_train_full.fillna(feature_means)\nX_test = X_test.fillna(feature_means)\n\nX_train_full = (X_train_full - feature_means) / (feature_stds + 1e-8)\nX_test = (X_test - feature_means) / (feature_stds + 1e-8)'

# %%
X_train_full = X_train_full.apply(pd.to_numeric, errors="coerce")
X_test = X_test.apply(pd.to_numeric, errors="coerce")

# %% [markdown]
# ### optimization

# %%
# Define Spearman correlation scorer
def spearman_correlation(y_true, y_pred):
    return spearmanr(y_true, y_pred)[0]

def pearson_correlation(y_true, y_pred):
    return pearsonr(y_true, y_pred)[0]
    
spearman_scorer = make_scorer(spearman_correlation)
pearson_scorer = make_scorer(pearson_correlation)

# Define scoring metrics
scoring = {
    'Spearman': spearman_scorer,
    'Pearson': pearson_scorer,
    'MAE': 'neg_mean_absolute_error',  # Convert later
    'RMSE': 'neg_root_mean_squared_error',  # Convert later
    'R2': 'r2'
}

# Define hyperparameter search spaces
param_distributions = {
    'TabPFN': {},  # No tuning needed
    
    'RandomForest': {
        'n_estimators': [10, 50, 100, 200, 500],
        'max_depth': [None, 5, 10, 20, 30, 50],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    },
    
    'XGBoost': {
        'n_estimators': [10, 50, 100, 200, 500],
        'max_depth': [2, 3, 5, 7, 10],
        'learning_rate': uniform(0.01, 0.3),
        'subsample': uniform(0.5, 0.5)
    },
    
    'SVM': {
        'C': uniform(0.1, 10),
        'epsilon': uniform(0.01, 1),
        'kernel': ['linear', 'rbf', 'poly']
    }
    
}

# %%
'''
# Create a directory to save models
save_dir = "../res/models/optimized_arch/"

# Models to compare
models = {
    'TabPFN': TabPFNRegressor(random_state=42),
    'RandomForest': RandomForestRegressor(random_state=42),
    'XGBoost': XGBRegressor(random_state=42),
    'SVM': SVR()
}

# Dictionary to store best hyperparameters & scores
best_results = {}
cv_scores = {}

# Define cross-validation folds
cv_folds = 5

for name, model in models.items():
    print(f"🔍 Tuning {name}...")

    if name in ["TabPFN"]:
        # No tuning needed
        best_results[name] = model
    else:
        # Perform Randomized Search for hyperparameter tuning
        random_search = RandomizedSearchCV(
            estimator=model,
            param_distributions=param_distributions[name],
            n_iter=40,  # Number of random samples
            cv=cv_folds,
            scoring='neg_root_mean_squared_error',  # Optimizing RMSE
            n_jobs=-1,
            random_state=42
        )
        random_search.fit(X_train_full, y_train_full)  # ✅ Use only training data
        best_results[name] = random_search.best_estimator_

        print(f"✅ Best parameters for {name}: {random_search.best_params_}\n")

    # Save the trained model
    model_path = os.path.join(save_dir, f"{name}.pkl")
    joblib.dump(best_results[name], model_path)
    print(f"💾 Saved {name} model to {model_path}")

    # Cross-validate best model to get all validation scores
    cv_results = cross_validate(best_results[name], X_train_full, y_train_full, cv=cv_folds, scoring=scoring, n_jobs=-1)
    
    # Store mean scores across folds
    cv_scores[name] = {
        'Spearman': np.mean(cv_results['test_Spearman']),
        'Pearson': np.mean(cv_results['test_Pearson']),
        'MAE': -np.mean(cv_results['test_MAE']),  # Convert negative MAE back
        'RMSE': -np.mean(cv_results['test_RMSE']),  # Convert negative RMSE back
        'R2': np.mean(cv_results['test_R2'])
    }

# Display results
df_best_params = pd.DataFrame(
    {name: model.get_params() for name, model in best_results.items()}
).T

df_cv_scores = pd.DataFrame(cv_scores).T
'''
# Out:
# '\n# Create a directory to save models\nsave_dir = "../res/models/optimized_arch/"\n\n# Models to compare\nmodels = {\n    \'TabPFN\': TabPFNRegressor(random_state=42),\n    \'RandomForest\': RandomForestRegressor(random_state=42),\n    \'XGBoost\': XGBRegressor(random_state=42),\n    \'SVM\': SVR()\n}\n\n# Dictionary to store best hyperparameters & scores\nbest_results = {}\ncv_scores = {}\n\n# Define cross-validation folds\ncv_folds = 5\n\nfor name, model in models.items():\n    print(f"🔍 Tuning {name}...")\n\n    if name in ["TabPFN"]:\n        # No tuning needed\n        best_results[name] = model\n    else:\n        # Perform Randomized Search for hyperparameter tuning\n        random_search = RandomizedSearchCV(\n            estimator=model,\n            param_distributions=param_distributions[name],\n            n_iter=40,  # Number of random samples\n            cv=cv_folds,\n            scoring=\'neg_root_mean_squared_error\',  # Optimizing RMSE\n            n_jobs=-1,\n    
# ...

# %%
#df_best_params

# %%
#df_cv_scores

# %% [markdown]
# # Make final fit and evaluate

# %%
# Evaluation Metrics
def evaluate_regression_metrics(y_true, y_pred):
    loss = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(loss)
    r2 = r2_score(y_true, y_pred)
    
    if np.std(y_true) == 0 or np.std(y_pred) == 0:
        spearman_corr = np.nan
        pearson_corr = np.nan
    else:
        try:
            spearman_corr, _ = spearmanr(y_true, y_pred)
            pearson_corr, _ = pearsonr(y_true, y_pred)
        except ValueError:
            spearman_corr = np.nan
            pearson_corr = np.nan
    
    return {
        'loss': loss,
        'spearman_corr': spearman_corr,
        'pearson_corr': pearson_corr,
        'mae': mae,
        'rmse': rmse,
        'r2': r2
    }

# %%
tabpfn_reg = TabPFNRegressor(device='auto')
tabpfn_reg.fit(X_train_full, y_train_full)
y_test_pred = tabpfn_reg.predict(X_test)
evaluate_regression_metrics(y_test, y_test_pred)
# Out:
# {'loss': 0.8972180423642452,
#  'spearman_corr': 0.6932689443405023,
#  'pearson_corr': 0.671671136836083,
#  'mae': 0.7108057041598361,
#  'rmse': 0.9472159428368196,
#  'r2': 0.4437123634124486}

# %%
y_train_pred = tabpfn_reg.predict(X_train_full)
evaluate_regression_metrics(y_train_full, y_train_pred)
# Out:
# {'loss': 0.5717457764195019,
#  'spearman_corr': 0.8190344106102999,
#  'pearson_corr': 0.8008948920727014,
#  'mae': 0.5675496912887191,
#  'rmse': 0.7561387282896584,
#  'r2': 0.6383198987263657}

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tabpfn import TabPFNRegressor  # Ensure you have TabPFN installed

# Choose scaler: MinMaxScaler (0-1) or StandardScaler (mean 0, std 1)
scaler = StandardScaler()
# scaler = MinMaxScaler()

# Fit scaler on the training targets and transform
y_train_full_scaled = scaler.fit_transform(y_train_full.values.reshape(-1, 1)).flatten()

# Train TabPFNRegressor
tabpfn_reg = TabPFNRegressor(device='auto')
tabpfn_reg.fit(X_train_full, y_train_full_scaled)

# Predict and inverse transform the predictions
y_test_pred_scaled = tabpfn_reg.predict(X_test)
y_test_pred = scaler.inverse_transform(y_test_pred_scaled.reshape(-1, 1)).flatten()

# Evaluate regression performance
evaluate_regression_metrics(y_test, y_test_pred)
# Out:
# {'loss': 0.8972179607045456,
#  'spearman_corr': 0.6932689443405023,
#  'pearson_corr': 0.6716711788222964,
#  'mae': 0.710805676826402,
#  'rmse': 0.9472158997317062,
#  'r2': 0.4437124140425954}

# %%
np.std(y_test_pred_scaled)
# Out:
# 0.7506661

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Load your dataset (replace with actual data)
# X should be your feature matrix, y should be your target variable
# Example: X, y = load_your_data()

# Split data into training and testing sets

# Define XGBoost parameters for regression
params = {
    'learning_rate': 0.06048731265187917,
    'max_depth': 2,
    'n_estimators': 200,
    'subsample': 0.681814801189647,
    'objective': 'reg:squarederror'  # Use regression objective
}

# Train XGBoost regressor
model = xgb.XGBRegressor(**params)
model.fit(X_train_full, y_train_full)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model using RMSE
evaluate_regression_metrics(y_test, y_pred)
# Out:
# {'loss': 0.9259158079672193,
#  'spearman_corr': 0.676026773464803,
#  'pearson_corr': 0.6553159806370201,
#  'mae': 0.7513152960816623,
#  'rmse': 0.9622451911894491,
#  'r2': 0.42591935051164354}
